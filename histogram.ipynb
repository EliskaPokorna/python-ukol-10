# %% [markdown]
# # Zadání
#
# - Načti si tato data do tabulky a vytvoř histogram. Nastav vhodně hranice skupin histogramu (parametr bins), aby byl graf přehledný a snadno interpretovatelný.

# %%
import pandas
import matplotlib.pyplot as plt

platy = pandas.read_csv("platy_2021_02.csv")

bins = [30000, 35000, 40000, 45000, 50000, 55000, 60000]
plt.hist(platy['plat'], bins=bins, edgecolor="black")

plt.xlabel('Plat')
plt.ylabel('Počet zaměstnanců')
plt.title('Histogram platů zaměstnanců')
plt.show()

# %% [markdown]
# ## Nepovinný bonus 1
#
# - Vrať se k práci se souborem temperature.csv, který obsahuje informace o průměrné teplotě v různých městech v listopadu 2017.
# - Vytvoř tabulku, která bude obsahovat údaje o teplotě za města Helsinki, Miami Beach a Tokyo.
# - Vytvoř krabicový graf a porovnej rozsah teplot v těchto městech.

# %%
import pandas
import matplotlib.pyplot as plt

temperature = pandas.read_csv("temperature.csv")

# %%
vybrana_mesta = temperature[temperature["City"].isin(["Helsinki", "Miami Beach", "Tokyo"])]
vybrana_mesta.pivot_table(index="Day", columns="City", values="AvgTemperature")
# Out:
# City  Helsinki  Miami Beach  Tokyo
# Day
# 1         29.6         74.6   59.1
# 2         29.5         76.8   62.3
# 3         35.1         77.4   64.1
# 4         44.5         77.4   59.6
# 5         45.5         77.2   57.0
# 6         43.8         78.6   60.4
# 7         36.0         78.8   64.0
# 8         38.6         79.0   62.5
# 9         42.4         80.0   59.0
# 10        43.0         80.2   62.1
# 11        40.5         79.1   59.5
# 12        35.7         80.8   55.1
# 13        34.6         79.2   56.8
# 14        33.1         79.7   56.2
# 15        34.4         75.4   56.7
# 16        36.1         75.0   53.7
# 17        40.6         73.8   53.1
# 18        39.8         75.1   53.5
# 19        37.2         75.2   48.9
# 20        33.0         74.5   46.6
# 21        32.4         74.4   48.2
# 22        32.3         77.3   48.7
# 23        33.5         77.4   53.4
# 24        41.9         75.9   50.3
# 25        36.0         72.1   50.5
# ...

# %%
plt.title("Porovnání teplot ve městech")
plt.xlabel("Měto")
plt.ylabel("Průměrná teplota")

vybrana_mesta.boxplot()
plt.show()
